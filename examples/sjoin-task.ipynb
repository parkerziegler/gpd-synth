# %%
import geopandas

# %%
def load_dataset(name): return geopandas.read_file(geopandas.datasets.get_path(name))

# %%
world = load_dataset('naturalearth_lowres')
cities = load_dataset('naturalearth_cities')

joined = geopandas.sjoin(cities, world, how='inner', predicate='intersects')
output = joined[['name_left', 'geometry', 'name_right', 'gdp_md_est']]

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
cities.head()
# Out:
#            name                   geometry
# 0  Vatican City  POINT (12.45339 41.90328)
# 1    San Marino  POINT (12.44177 43.93610)
# 2         Vaduz   POINT (9.51667 47.13372)
# 3    Luxembourg   POINT (6.13000 49.61166)
# 4       Palikir  POINT (158.14997 6.91664)

# %%
joined = geopandas.sjoin(cities, world, how='inner', predicate='intersects')
joined.head()
# Out:
#         name_left                   geometry  index_right   pop_est continent  \
# 0    Vatican City  POINT (12.45339 41.90328)          141  62137802    Europe
# 1      San Marino  POINT (12.44177 43.93610)          141  62137802    Europe
# 192          Rome  POINT (12.48131 41.89790)          141  62137802    Europe
# 2           Vaduz   POINT (9.51667 47.13372)          114   8754413    Europe
# 184        Vienna  POINT (16.36469 48.20196)          114   8754413    Europe
#
#     name_right iso_a3  gdp_md_est
# 0        Italy    ITA   2221000.0
# 1        Italy    ITA   2221000.0
# 192      Italy    ITA   2221000.0
# 2      Austria    AUT    416600.0
# 184    Austria    AUT    416600.0

# %%
output = joined[['name_left', 'geometry', 'name_right', 'gdp_md_est']]
output.head()
# Out:
#         name_left                   geometry name_right  gdp_md_est
# 0    Vatican City  POINT (12.45339 41.90328)      Italy   2221000.0
# 1      San Marino  POINT (12.44177 43.93610)      Italy   2221000.0
# 192          Rome  POINT (12.48131 41.89790)      Italy   2221000.0
# 2           Vaduz   POINT (9.51667 47.13372)    Austria    416600.0
# 184        Vienna  POINT (16.36469 48.20196)    Austria    416600.0
